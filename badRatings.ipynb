# %% [markdown]
# ## definition des fonctions ( voir plus bas pour les ratings )

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from trueskill import mathematics,TrueSkill, Rating, quality_1vs1, rate_1vs1
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
x = np.linspace(2,48,100)
bruno, jerem = Rating(25), Rating(25)  # assign  ratings
env=TrueSkill(draw_probability=0)
TrueSkill.DRAW_PROBABILITY=0

def Pwin(rA=Rating(), rB=Rating()):
    deltaMu = rA.mu - rB.mu
    rsss = sqrt(rA.sigma**2 + rB.sigma**2)
    return TrueSkill().cdf(deltaMu/rsss)

def updateRatingsAndPrint(jeremVictoryList):
    global bruno
    global jerem
    for victoire in jeremVictoryList:
        if(victoire):
            jerem,bruno   = rate_1vs1(jerem, bruno,env=env)
        else:
            bruno, jerem = rate_1vs1(bruno, jerem,env=env)
    p1=plt.plot(x,mlab.normpdf(x,bruno.mu,bruno.sigma),color='r')
    p2=plt.plot(x,mlab.normpdf(x,jerem.mu,jerem.sigma),color='b')
    plt.show()
    print( "Niveau de bruno en rouge \nNiveau de jerem en bleu")
    print('Estimation à {:.1%} de chance pour jerem de gagner ses prochains matchs'.format(Pwin(jerem,bruno)))

# %% [markdown]
# ## Samedi 06 septembre 2014 : 2 victoires de Jerem,
# (la deuxième étant noblement accordée)

# %%
updateRatingsAndPrint([1,1])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 90.2% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Dimanche 07 septembre 2014 : 1 victoire de Jerem, 2 victoires pour Bruno

# %%
updateRatingsAndPrint([1,0,0])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 27.5% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Samedi 13 septembre 2014 : 2 victoires de Jerem, 1 victoire pour bruno

# %%
updateRatingsAndPrint([1,1,0])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 50.2% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Dimanche 14 septembre 2014 : 3 victoires de Bruno

# %%
updateRatingsAndPrint([0,0,0])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 9.6% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Samedi 20 septembre 2014 : 1 victoire de Bruno, 2 victoires de Jerem

# %%
updateRatingsAndPrint([1,1,0])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 32.3% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Dimanche 21 septembre 2014 : 2 victoires de Jerem

# %%
updateRatingsAndPrint([1,1])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 66.9% de chance pour jerem de gagner ses prochains matchs

# %% [markdown]
# ## Samedi 28 septembre 2014 : 2 victoires de Bruno
# On notera quand même la santé défaillante de Jerem ce jour-ci

# %%
updateRatingsAndPrint([0,0])
# Out:
# Niveau de bruno en rouge
# Niveau de jerem en bleu
# Estimation à 34.6% de chance pour jerem de gagner ses prochains matchs
